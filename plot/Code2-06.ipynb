# %% [markdown]
# <div dir="rtl">
#
# #   زیرنمودار
# </div>

# %%
import matplotlib.pyplot as plt
import  numpy as np

# %%
x=np.linspace(-2,2,100)
y1=x
y2=np.sin(x)
y3=np.cos(x)
y4=x**2
y5=x**3
y6=np.sin(x)+np.cos(x)
plt.subplot(2,3,1)
plt.plot(x,np.exp(x))
plt.subplot(2,3,2)
plt.plot(x,y2)
plt.subplot(2,3,3)
plt.plot(x,y3)
plt.subplot(2,3,4)
plt.plot(x,y4)
plt.subplot(2,3,5)
plt.plot(x,y5)
plt.subplot(2,3,6)
plt.plot(x,y6)
plt.show()
